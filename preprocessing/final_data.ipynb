# %%
import sys
sys.path.append('..')

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm
from utils.preprocessing import *
import core.config as conf

# %%
data_path = '/dataset/final_data/raw_data/part-00000'
df = read_data(data_path)

# %% [markdown]
# ## Train-valid split

# %%
len(df)
# Out:
# 14271144

# %%
train_size = 11416915

# %%
df
# Out:
#                                                 text_tokens  \
# 0         101\t56898\t137\t99900\t40517\t49457\t10305\t1...
# 1         101\t27158\t42682\t14444\t188\t16218\t10173\t4...
# 2         101\t56898\t137\t32385\t61620\t12659\t22471\t1...
# 3         101\t10117\t11424\t25441\t10135\t100\t14120\t1...
# 4         101\t55531\t8641\t6824\t1933\t15802\t14725\t10...
# ...                                                     ...
# 14271139  101\t3815\t1975\t111793\t14120\t131\t120\t120\...
# 14271140  101\t149\t11565\t30271\t10146\t11395\t216\t107...
# 14271141  101\t91327\t10107\t10142\t11223\t86981\t12023\...
# 14271142  101\t30929\t71033\t10858\t11273\t83259\t11090\...
# 14271143  101\t13740\t19153\t10107\t28974\t11008\t10192\...
#
#                                   hashtags                          tweet_id  \
# 0                                      NaN  63F05256F79E7A098BF78E508967014B
# 1         A338C5C1637BEDA847BC1237241145BC  620B83CB3963A1A24D59AD1CDA2C1E10
# 2                                      NaN  5614711FC32B65D6315447666196B362
# 3                                      NaN  50733D80B3733168FBEBA7B7E6F76328
# 4                                      NaN  9AF23572E97D092F188F89B98026F970
# ...                                    ...                               ...
# 14271139                               NaN  4280B9A207B56696F8D45C13ACD05379
# 14271140                               NaN  EE9918C5D25101CC58C2ED6DD70CD28E
# 14271141                               NaN  F0FFDEDC4B49659C30EB4915114ACA18
# 14271142                               NaN  7F08348140C63B8348F157B5AA5E730A
# 14271143                               NaN  3DA4FA3E2C5DB8E37F92A4AF889D5E53
#
#                  media links domains tweet_type  \
# 0                  NaN   NaN     NaN    Retweet
# 1                  NaN   NaN     NaN   TopLevel
# 2                Video   NaN     NaN    Retweet
# 3         Photo\tPhoto   NaN     NaN   TopLevel
# 4                  NaN   NaN     NaN   TopLevel
# ...                ...   ...     ...        ...
# 14271139         Photo   NaN     NaN   TopLevel
# 14271140           NaN   NaN     NaN   TopLevel
# 14271141         Photo   NaN     NaN   TopLevel
# 14271142  Photo\tPhoto   NaN     NaN   TopLevel
# 14271143           NaN   NaN     NaN   TopLevel
#
#                                   language  tweet_timestamp  \
# 0         B0FA488F2911701DD8EC5B1EA5E322D8       1614675246
# 1         B8B04128918BBF54E2E178BFF1ABA833       1614476822
# 2         E7F038DE3EAD397AEC9193686C911677       1614593752
# 3         488B32D24BD4BB44172EB981C1BCA6FA       1614316064
# 4         E7F038DE3EAD397AEC9193686C911677       1614349500
# ...                                    ...              ...
# 14271139  E7F038DE3EAD397AEC9193686C911677       1614342582
# 14271140  488B32D24BD4BB44172EB981C1BCA6FA       1614251200
# 14271141  488B32D24BD4BB44172EB981C1BCA6FA       1614536014
# 14271142  488B32D24BD4BB44172EB981C1BCA6FA       1614450237
# 14271143  B8B04128918BBF54E2E178BFF1ABA833       1614220291
#
#                                 creator_id  ...  \
# 0         7D3C3D00D14613287ABC9C140FE26A54  ...
# 1         6B1525449DEC20FFB77526D2A86B1563  ...
# 2         437B4EF4128B8FE8079BB81A5ACF656C  ...
# 3         96BD65F70F3659D17C532D17EE89E378  ...
# 4         0076D50D707E65CA929490588036C58A  ...
# ...                                    ...  ...
# 14271139  FA496FB5DBD79BEA4BBEACB6ED6A97A6  ...
# 14271140  5F865A9042F72D12A3907562BA4B9DCB  ...
# 14271141  AEA4C2C14C8DAF353BA1AECC378FED4E  ...
# 14271142  65C0102FC1A08A22E6AEEE868AF1DAA3  ...
# 14271143  AB1E64105655F93C35692479A1913547  ...
#
#                                 engager_id  engager_follower_count  \
# 0         05DAD6CEF374FE6DBB6A845828C14E46                     437
# 1         F16C923EEEF0C56FA8E03C9947A70CAB                    1316
# 2         86FADA0FC87B8668B34C4C9EA41EEF54                     417
# 3         CF3CCAA5F335FC784FD5635CF433688C                       3
# 4         AC30E66EC27F4C07FE1278D6DDC2FBEB                     136
# ...                                    ...                     ...
# 14271139  077E49272FD5B88CA8ACB15FE76173C3                      60
# 14271140  6F7F7E222046A73F03A83E38B9A6E5AA                     980
# 14271141  58F8F17AC0568979B0350C718DFFCFAF                      10
# 14271142  9A640AEA31AE5B22B9793A9791E8399A                     435
# 14271143  51BDB368E8107809DBAF75F037DE05A8                     279
#
#           engager_following_count  engager_is_verified  \
# 0                             366                False
# 1                            1261                False
# 2                             411                False
# 3                              60                False
# 4                             211                False
# ...                           ...                  ...
# 14271139                      425                False
# 14271140                      298                False
# 14271141                      164                False
# 14271142                     2245                False
# 14271143                      879                False
#
#          engager_account_creation  creator_follows_engager  reply_timestamp  \
# 0                      1540017514                     True              NaN
# 1                      1470337501                     True              NaN
# 2                      1576241664                     True              NaN
# 3                      1602401250                    False              NaN
# 4                      1571210700                     True              NaN
# ...                           ...                      ...              ...
# 14271139               1499081516                    False              NaN
# 14271140               1488303474                     True     1.614251e+09
# 14271141               1556532857                    False              NaN
# 14271142               1581552902                    False              NaN
# 14271143               1441728457                    False              NaN
#
#           retweet_timestamp  comment_timestamp  like_timestamp
# 0                       NaN                NaN    1.614675e+09
# 1                       NaN                NaN             NaN
# 2                       NaN                NaN             NaN
# 3                       NaN                NaN    1.614357e+09
# 4                       NaN                NaN             NaN
# ...                     ...                ...             ...
# 14271139                NaN                NaN    1.614343e+09
# 14271140                NaN                NaN             NaN
# 14271141                NaN                NaN    1.614559e+09
# 14271142                NaN                NaN    1.614464e+09
# 14271143                NaN                NaN    1.614266e+09
#
# [14271144 rows x 24 columns]

# %%
train = df[:train_size]
valid = df[train_size:]

# %%
train.to_csv(f"/dataset/final_data/dataset/train/part-0", header=False, sep='\x01', index=False)
valid.to_csv(f"/dataset/final_data/dataset/valid/part-0", header=False, sep='\x01', index=False)

# %% [markdown]
# ## trian split (2)

# %%
df = read_data('/dataset/final_data/dataset/train/part-0')

# %%
train_size = len(df) // 2

# %%
train1 = df[:train_size]
train2 = df[train_size:]

# %%
train1.to_csv(f"/dataset/final_data/dataset/train/part-01", header=False, sep='\x01', index=False)
train2.to_csv(f"/dataset/final_data/dataset/train/part-02", header=False, sep='\x01', index=False)

# %%
train1

# %%
train2

# %% [markdown]
# ## Cross-validation-data

# %%
df['day'] = pd.to_datetime( df['tweet_timestamp'] , unit='s' ).dt.day

# %%
print('train-ad:', df['day'].min(), df['day'].max())

# %%
df['day'].unique()
# Out:
# array([ 2, 28,  1, 26, 27,  3, 25])
